# %%
import os
from IPython.display import FileLink, display

# O conteúdo HTML da surpresa
html = """
<!DOCTYPE html>
<html lang="pt-br">
<head>
    <meta charset="UTF-8">
    <title>Para a minha futura médica 💙🌊</title>
    <style>
        body {
            background: linear-gradient(to right, #d0eafc, #f0faff);
            font-family: 'Arial', sans-serif;
            text-align: center;
            padding: 50px;
            color: #002b5b;
        }
        h1 {
            font-size: 3em;
            color: #0077b6;
            margin-bottom: 20px;
        }
        .mensagem {
            display: none;
            font-size: 1.5em;
            margin-top: 30px;
            animation: aparecer 2s ease-in-out forwards;
        }
        button {
            padding: 15px 25px;
            font-size: 1.2em;
            background-color: #00b4d8;
            color: white;
            border: none;
            border-radius: 10px;
            cursor: pointer;
            box-shadow: 0 0 10px #caf0f8;
        }
        .coracao {
            font-size: 2em;
            animation: pulsar 1.5s infinite;
            color: #ef476f;
        }
        @keyframes pulsar {
            0%, 100% { transform: scale(1); }
            50% { transform: scale(1.3); }
        }
        @keyframes aparecer {
            from { opacity: 0; transform: translateY(20px); }
            to { opacity: 1; transform: translateY(0); }
        }
        .assinatura {
            margin-top: 40px;
            font-size: 1em;
            color: #495057;
        }
        iframe {
            margin-top: 30px;
            border-radius: 12px;
        }
    </style>
</head>
<body>

    <h1>Oi, Mariana 💖</h1>
    <p class="coracao">💓💓💓</p>

    <button onclick="mostrarMensagem()">Clique aqui</button>

    <div class="mensagem" id="mensagem">
        <p>Eu te amo demais. Você é tudo pra mim.</p>
        <p>Seu jeito, sua força, sua doçura... tudo em você me inspira.</p>
        <p>Tenho tanto orgulho de você, da mulher incrível e da médica maravilhosa que você vai ser 🩺💘</p>
        <p>Você é meu presente mais precioso. Obrigado por existir.</p>
    </div>

    <div class="assinatura">
        Com amor, Henrique 🐻
    </div>

    <div style="margin-top: 40px;">
        <p style="font-size: 1.2em;">Dá o play aqui, meu amor 🎶</p>
        <iframe width="300" height="170" src="https://www.youtube.com/embed/xgA1IjU44fY?loop=1&playlist=xgA1IjU44fY"
            title="Oceano - Djavan"
            frameborder="0"
            allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture"
            allowfullscreen>
        </iframe>
    </div>

    <script>
        function mostrarMensagem() {
            document.getElementById("mensagem").style.display = "block";
        }
    </script>

</body>
</html>
"""

# Caminho do arquivo na pasta atual
caminho = os.path.join(os.getcwd(), "mariana_surpresa.html")

# Criar o arquivo
with open(caminho, "w", encoding="utf-8") as f:
    f.write(html)

print(f"Arquivo criado em: {caminho}")

# Mostrar link para download direto no notebook
display(FileLink(caminho))
# Out:
# Arquivo criado em: c:\Users\henrique.rleme\AppData\Local\Programs\Microsoft VS Code\mariana_surpresa.html
# c:\Users\henrique.rleme\AppData\Local\Programs\Microsoft VS Code\mariana_surpresa.html
